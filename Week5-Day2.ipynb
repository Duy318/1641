# %%
import pandas as pd
movieData = pd.read_csv("MovieData.csv")
movieData.head(100)
# Out:
#                            Film      Genre  Rotten Tomatoes Ratings %  \
# 0         (500) Days of Summer      Comedy                         87
# 1                   10,000 B.C.  Adventure                          9
# 2                    12 Rounds      Action                         30
# 3                     127 Hours  Adventure                         93
# 4                     17 Again      Comedy                         55
# ..                          ...        ...                        ...
# 95                    Disturbia   Thriller                         67
# 96                 Dolphin Tale      Drama                         84
# 97  Don't Be Afraid Of The Dark     Horror                         59
# 98                     Doomsday     Action                         48
# 99                        Doubt      Drama                         78
#
#     Audience Ratings %  Budget (million $)  Year of release
# 0                   81                   8             2009
# ...

# %%
print(movieData["Film"])
# Out:
# 0      (500) Days of Summer
# 1                10,000 B.C.
# 2                 12 Rounds
# 3                  127 Hours
# 4                  17 Again
#                ...
# 554            Your Highness
# 555          Youth in Revolt
# 556                   Zodiac
# 557              Zombieland
# 558                Zookeeper
# Name: Film, Length: 559, dtype: object

# %%
movieData[movieData["Year of release"] == 2007]
# Out:
#                                Film     Genre  Rotten Tomatoes Ratings %  \
# 7                  30 Days of Night    Horror                         50
# 10                       88 Minutes     Drama                          5
# 16              Across the Universe   Romance                         54
# 20    Alien vs. Predator -- Requiem    Horror                         14
# 25                American Gangster  Thriller                         79
# ..                              ...       ...                        ...
# 525                        Waitress   Romance                         89
# 526  Walk Hard: The Dewey Cox Story    Comedy                         75
# 534                We Own the Night     Drama                         55
# 544                       Wild Hogs    Comedy                         14
# 556                          Zodiac  Thriller                         89
#
#      Audience Ratings %  Budget (million $)  Year of release
# ...

# %%
movieData[movieData["Genre"] == "Action"]
# Out:
#                           Film   Genre  Rotten Tomatoes Ratings %  \
# 2                   12 Rounds   Action                         30
# 5                         2012  Action                         39
# 15                   Abduction  Action                          4
# 29                   Appaloosa  Action                         77
# 30                    Armored   Action                         40
# ..                         ...     ...                        ...
# 531                  Watchmen   Action                         64
# 542                  Whiteout   Action                          7
# 546  X-Men Origins: Wolverine   Action                         37
# 547         X-Men: First Class  Action                         87
# 557                Zombieland   Action                         90
#
#      Audience Ratings %  Budget (million $)  Year of release
# 2                    52                  20             2009
# ...

# %%
from matplotlib import pyplot as plt
x, y = [1600, 1700, 1800, 1900, 2000] , [0.2, 0.5, 1.1, 2.2, 7.7]
plt.plot(x, y)
plt.title("World Population Over Time")
plt.xlabel("Year")
plt.ylabel("Population(billions)")
plt.show()

# %%
x1, y1 = [1600, 1700, 1800, 1900, 2000] , [0.2, 0.5, 1.1, 2.2, 7.7]
x2, y2 = [1600, 1700, 1800, 1900, 2000] , [1, 1, 2, 3, 4]

plt.plot(x1, y1, "gx-", label="Actual")
plt.plot(x2, y2, "bo--", label="Fake")

plt.title("World Population Over Time")
plt.xlabel("Year")
plt.ylabel("Population(billions)")
plt.legend()
plt.show()

# %%
x1, y1 = [1600, 1700, 1800, 1900, 2000] , [0.2, 0.5, 1.1, 2.2, 7.7]
x2, y2 = [1600, 1700, 1800, 1900, 2000] , [1, 1, 2, 3, 4]
x3, y3 = [1600, 1700, 1800, 1900, 2000] , [1, 4, 7, 8, 9]

plt.plot(x1, y1, "rx-", label="Actual")
plt.plot(x2, y2, "bo--", label="Fake")
plt.plot(x3, y3, "gx--", label="Guess")

plt.title("World Population Over Time")
plt.xlabel("Year")
plt.ylabel("Population(billions)")
plt.legend()
plt.show()

# %%
num_people, categories = [4, 8, 3, 6, 2] , ["Comedy", "Action", "Thriller", "Romance", "Horror"]
plt.bar(categories, num_people)
plt.title("Favorite Movie Category", fontsize=24)
plt.xlabel("Category", fontsize=16)
plt.ylabel("# of People", fontsize=16)
plt.xticks(fontname="Fantasy")
plt.yticks(fontname="Fantasy")
plt.show()

# %%
males, females = [72, 68, 65, 77, 73, 71, 69] , [60, 65, 68, 61, 63, 64]
heights = [males, females]
plt.figure(figsize=(15, 8))
plt.boxplot(heights)
plt.title("Height by Gender", fontsize=22)
plt.ylabel("Height(inches)", fontsize=14)
plt.xlabel("Gender", fontsize=14)
plt.show()

# %%
from random import randint

height = [randint(58, 78) for x in range(20)]
weight = [randint(90, 250) for x in range(20)]

plt.scatter(weight, height)
plt.title("Height-Weight Distribution")
plt.xlabel("Weight (lbs)")
plt.ylabel("Height (inches)")
plt.show()

# %%
import numpy as np
np.random.seed(5)
ages=[np. random.normal(loc = 40, scale=10) for x in range(1000)]
plt.hist(ages, bins=45)
plt.title("Ages per Population")
plt.xlabel("Age")
plt.ylabel("# of People")
plt.show()

# %%
florida = [np.random.normal(loc=60, scale=15) for x in range(1000)]
california = [np.random.normal(loc=35, scale=5) for x in range(1000)]

plt.hist(florida, bins=45, color="r", alpha=0.4)

plt.hist(california, bins=45, color="b", alpha=0.4)

plt.show()

plt.hist(california, bins=45, color="g", alpha=1)
plt.show()

# %%
from random import randint

height = [randint(58, 78) for x in range(20)]
weight = [randint(90, 250) for x in range(20)]
age = [randint(18, 65) for x in range(20)]

plt.scatter(weight, height, c=age)
plt.title("Height-Weight Distribution")
plt.xlabel("Weight (lbs)")
plt.ylabel("Height (inches)")
plt.colorbar(label="Age")
plt.show()

# %%
from matplotlib import pyplot as plt
import pandas as pd

movieData = pd.read_csv("MovieData.csv")
movieData.columns = ["Film", "Genre", "CriticRatings", "AudienceRatings", "Budget", "Year"]
df = movieData.groupby("Year", as_index=False).sum().head()

x = df.Year
y = df.Budget

plt.plot(x, y)
plt.title("Budget Usage for Movies")
plt.xlabel("Year")
plt.ylabel("Total Budget(Millions)")
plt.show()

# %%
x, y =[1600, 1700, 1800, 1900, 2000] , [0.2, 0.5, 1.1, 2.2, 7.7]
plt.plot(x, y, "bo-")
plt.title("World Population Over Time")
plt.xlabel("Year")
plt.ylabel("Population(billions)")
plt.savefig("population.jpg")

# %%
df = movieData.groupby("Genre", as_index=False).count().head(20)

num_people = df.Budget
categories = df.Genre

plt.bar(categories, num_people)
plt.title("Movie Category")
plt.xlabel("Category")
plt.ylabel("Budget Usage (Millions)")
plt.show()

# %%
df = movieData.groupby("Genre", as_index=False).count().head(100)
budget = df.Budget
category = df.Genre

plt.scatter(category, budget)
plt.title("Budget-Category Distribution")
plt.xlabel("Category")
plt.ylabel("Total Budget (millions)")
plt.show()

# %%
df = movieData.groupby("Genre", as_index=False).count().head(100)
rating=df.AudienceRatings
year=df.Year
budget = df.Budget


plt.scatter(year, rating, c= budget)
plt.title("Movie Rating and Budget Over Time")
plt.xlabel("Year")
plt.ylabel("AudienceRatings")
plt.colorbar(label="Budget(Million)")
plt.grid(True)
plt.show()

# %%
from matplotlib import pyplot as plt
import seaborn as sns

# %matplotlib inline
sns.set_style("darkgrid")

j = sns.jointplot(data=movieData, x="CriticRatings", y="AudienceRatings", kind="hex")

# %%
j = sns.jointplot(data=movieData, x="CriticRatings", y="Budget", kind="hex")
j = sns.jointplot(data=movieData, x="AudienceRatings", y="Budget", kind="hex")

# %%
h=sns.displot(movieData.AudienceRatings)

# %%
plt.hist([movieData[movieData.Genre =="Comedy"].Budget, movieData[movieData.Genre =="Action"].Budget],stacked=True)
plt.show()

# %%
plt.hist(movieData[movieData.Genre =="Drama"].Budget)
plt.hist(movieData[movieData.Genre =="Action"].Budget)
plt.hist(movieData[movieData.Genre =="Comedy"].Budget)
plt.hist(movieData[movieData.Genre =="Horror"].Budget)
plt.show()

# %%
n
